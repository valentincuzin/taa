# %% [markdown]
# # TP1 Détection d'anomalie

# %%
import numpy as np

np.set_printoptions(threshold=10000, suppress=True)
import pandas as pd
import warnings
import matplotlib.pyplot as plt

warnings.filterwarnings("ignore")

# %% [markdown]
# ## Dataset Mouse

# %%
data = np.loadtxt('mouse.txt', delimiter=' ')
data = pd.DataFrame(data)
data.head()
# Out:
#           0         1
# 0  0.456601  0.432806
# 1  0.611378  0.528625
# 2  0.450299  0.711606
# 3  0.639015  0.460744
# 4  0.628957  0.323470

# %%
plt.scatter(data[0], data[1])

# %% [markdown]
# ## Dataset CreditCard

# %% [markdown]
# ## Dataset KFFCup99
